# %%
import sys; sys.path.insert(1, "./../")
from src.runpipe import Pipeline_P2
from settings import Settings_P2

# %matplotlib inline

# %%
set = Settings_P2()
set.PATH21TS = "./../data/TS21/lfcal_training_set_8-2020.hdf5"
set.PATHFGTS = "./../data/TSFG/Nreg_1"
set.ANT1 = ["dipole"]
set.ANT2 = ["sinuous"]
set.LST_2_FIT = 1
set.printSettings()
# Out:
# ------------------ Settings for the pipeline ------------------
#
# Frequencies: Between (50 - 200) MHz with step size of 1 MHz.
# 21 TS: ./../data/TS21/lfcal_training_set_8-2020.hdf5
# FG TS: ./../data/TSFG/Nreg_1
# Number of time bins for 1 antenna: 1
# Start time of each time bin ant-1: 00:00:00
# Start time of each time bin ant-2: 03:00:00
# Each value is this list is integrated for 6 bins of 30 min.
# Antenna design: ['dipole-sinuous']
# Integration time for each time bin: 12.0 h
# Total number of foreground modes: 80
# Total number of 21cm modes: 80
# Information Criterion: DIC
# Filename to store the info criteria: ./DIC_search.txt
# Visualization: True
# Save figures: False

# %%
pipeline = Pipeline_P2(nu=set.NU, lst2fit=set.LST_2_FIT, nLST=set.LST, ant=set.ANT, ant1=set.ANT1, ant2=set.ANT2,
                       path21TS=set.PATH21TS, pathFgTS=set.PATHFGTS, obsDate="2019-10-01", obsDateTime1=set.timeList1,
                       obsDateTime2=set.timeList2, intBins=set.intBins, numReg=1, fgModel="gsm", dT=set.dT,
                       modesFg=set.MODES_FG, modes21=set.MODES_21, quantity=set.QUANTITY, file=set.FNAME,
                       visual=set.VISUALS, index21=467)

# %%
_ = pipeline.runPipeline()
# Out:
# -------------------- Running the pipeline ---------------------
#
# Modelling set: Reading 21 modelling set...Done!
# Modelling set: Reading FG modelling set...Done!
# Modelling set: Reading FG modelling set...Done!
# Basis: Performing SVD of 21 modelling set...Done!
# Basis: Performing SVD of FG modelling set...Done!
# Info Criterion: Calculating info criterion over grid...Done!
# Info Critetion: Searching for minima over the grid...Done!
# Info Criterion: IC is minimzed for 4 FG and 12 signal modes.
# Extractor: Extracting the 21cm signal...Done!
# Extractor: RMS uncertainty = 10.97 mK
# Extractor: Signal Bias Statistic = 1.04
# Extractor: Normalized Deviance = 1.10
# (4,
#  12,
#  346.67245452593284,
#  1.0434622235520143,
#  1.1002533375032617,
#  10.972306116922349)
